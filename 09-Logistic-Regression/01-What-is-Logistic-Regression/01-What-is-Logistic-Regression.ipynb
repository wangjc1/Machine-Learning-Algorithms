# %% [markdown]
# ## sigmoid 函数

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(t):
    return 1. / (1. + np.exp(-t))

# %%
x = np.linspace(-10, 10, 500)
x
sigmoid(x)
# Out:
# array([4.53978687e-05, 4.72542909e-05, 4.91866227e-05, 5.11979678e-05,
#        5.32915566e-05, 5.54707518e-05, 5.77390534e-05, 6.01001044e-05,
#        6.25576969e-05, 6.51157778e-05, 6.77784556e-05, 7.05500064e-05,
#        7.34348813e-05, 7.64377131e-05, 7.95633242e-05, 8.28167340e-05,
#        8.62031669e-05, 8.97280610e-05, 9.33970764e-05, 9.72161046e-05,
#        1.01191278e-04, 1.05328979e-04, 1.09635853e-04, 1.14118812e-04,
#        1.18785057e-04, 1.23642077e-04, 1.28697671e-04, 1.33959956e-04,
#        1.39437378e-04, 1.45138732e-04, 1.51073169e-04, 1.57250215e-04,
#        1.63679786e-04, 1.70372201e-04, 1.77338202e-04, 1.84588969e-04,
#        1.92136138e-04, 1.99991822e-04, 2.08168627e-04, 2.16679674e-04,
#        2.25538620e-04, 2.34759678e-04, 2.44357643e-04, 2.54347914e-04,
#        2.64746518e-04, 2.75570134e-04, 2.86836124e-04, 2.98562558e-04,
#        3.10768244e-04, 3.23472754e-04, 3.36696463e-04, 3.50460573e-04,
# ...

# %%
x = np.linspace(-10, 10, 500)

plt.plot(x, sigmoid(x))
plt.show()
