# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
delta = 0.025
# 生成代表X轴数据的列表
x = np.arange(-3.0, 3.0, delta)
# 生成代表Y轴数据的列表
y = np.arange(-2.0, 2.0, delta)
# 对x、y数据执行网格化
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
# 计算Z轴数据（高度数据）
Z = (Z1 - Z2) * 2
# 为等高线图填充颜色, 16指定将等高线分为几部分
plt.contourf(x, y, Z, 16, alpha = 0.75,
    cmap='rainbow')  # 使用颜色映射来区分不同高度的区域
# 绘制等高线
C = plt.contour(x, y, Z, 16,
    colors = 'black', # 指定等高线的颜色
    linewidth = 0.5) # 指定等高线的线宽
# 绘制等高线数据
plt.clabel(C, inline = True, fontsize = 10)
# 去除坐标轴
plt.xticks(())
plt.yticks(())
# 设置标题
plt.title("等高线图")
# 为两条坐标轴设置名称
plt.xlabel("纬度")
plt.ylabel("经度")
plt.show()

# %%
def f(x, y):
 return (1-x/2+x**3+y**5) * np.exp(-x**2-y**2)
 
# 生成x,y的数据
n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
 
# 把x,y数据生成mesh网格状的数据，因为等高线的显示是在网格的基础上添加上高度值
X, Y = np.meshgrid(x, y)
print(Y.shape)
Z = f(X, Y)

# 填充等高线
plt.contourf(X, Y, Z)
# 显示图表
# Out:
# (256, 256)

# %%
def plot_decision_boundary( axis):
    x0, x1 = np.meshgrid(
        np.linspace(axis[0], axis[1], int((axis[1]-axis[0])*2)).reshape(-1, 1),
        np.linspace(axis[2], axis[3], int((axis[3]-axis[2])*2)).reshape(-1, 1),
    )
    plt.scatter(x0,x1,marker='.',c='r',s=100) 
    
    n,m = x0.shape
    zz = np.vstack([np.zeros((n//2, m)),np.ones((n//2, m))])   
    
    #plt.contourf(x0, x1, zz, linewidth=5)

plot_decision_boundary( axis=[4, 7.5, 1.5, 4.5])
plt.show()

# %%
# 已知x, y, Z
x = np.linspace(0, 1,2)
y = np.linspace(0, 1,2)
x,y
# Out:
# (array([0., 1.]), array([0., 1.]))

# %%
# 建立网格
X, Y = np.meshgrid(x, y)
# 生成4个坐标： (0,0),(1,0),(0,1),(1,1)
X,Y
# Out:
# (array([[0., 1.],
#         [0., 1.]]), array([[0., 0.],
#         [1., 1.]]))

# %%
#Height
Z = [[0,1],[0,1]]
Z
# Out:
# [[0, 1], [0, 1]]

# %%
"""
x：指定 X 轴数据。
y：指定 Y 轴数据。
z：指定 X、Y 坐标对应点的高度数据。
colors：指定不同高度的等高线的颜色。
alpha：指定等高线的透明度。
cmap：指定等高线的颜色映射，即自动使用不同的颜色来区分不同的高度区域。
linewidths：指定等高线的宽度。
linestyles：指定等高线的样式。
"""
#赋值b后面要用到estyles='solid')
b = plt.contour(X, Y, Z, 1,colors='black', linewidths=0.2)
from matplotlib.colors import ListedColormap
custom_cmap = ListedColormap(['#EF9A9A','#FFF59D','#90CAF9'])
a = plt.contourf(X, Y, Z,1, linewidth=0.2, cmap=custom_cmap) 

# 添加colorbar，ticks在这里可省略
plt.colorbar(a)

#添加图内标签
plt.clabel(b, inline=True, fontsize=10)
plt.scatter(X,Y,marker='*',c='r',s=100)
plt.show()

# %%
def plot_decision_boundary(model, axis):
    #构造一个300x350的网格
    x0, x1 = np.meshgrid(
        np.linspace(axis[0], axis[1], int((axis[1]-axis[0])*100)).reshape(-1, 1),
        np.linspace(axis[2], axis[3], int((axis[3]-axis[2])*100)).reshape(-1, 1),
    )
    
    #x0.ravel()是矩阵向量化
    #np.c_是按行连接两个矩阵，就是把两矩阵左右相加，要求行数相等
    X_new = np.c_[x0.ravel(), x1.ravel()]
    #调用模型预测，返回预测结果
    y_predict = model.predict(X_new)
    #把预测结果作为等高线高度值
    #生成300x350个等高值，相当于每个小网格有一个等高度
    #如果y_predict包含两个分类{0,1},那么就相当于有两个等高值
    zz = y_predict.reshape(x0.shape)
    #填充等高面，不同的分类会被不同的颜色填充
    plt.contourf(x0, x1, zz, linewidth=5)
