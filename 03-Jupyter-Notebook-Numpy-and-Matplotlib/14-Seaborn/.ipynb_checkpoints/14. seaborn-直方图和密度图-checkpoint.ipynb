# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sns

# %%
s1 = Series(np.random.randn(1000))

# %% [markdown]
# ## 直方图

# %%
# 调用matplotlib函数画直方图
plt.hist(s1)
# Out:
# (array([ 18.,  60., 133., 273., 280., 156.,  65.,  13.,   1.,   1.]),
#  array([-2.95746197, -2.23023682, -1.50301167, -0.77578652, -0.04856138,
#          0.67866377,  1.40588892,  2.13311407,  2.86033922,  3.58756436,
#          4.31478951]),
#  <a list of 10 Patch objects>)

# %%
#调用seaborn库的distplot函数画直方图
sns.distplot(s1, bins=20, hist=True, kde=True, rug=True)

# %% [markdown]
# ## 密度图

# %%
s1.plot(kind='kde')

# %%
sns.kdeplot(s1, shade=True, color='r')

# %%
sns.rugplot()
